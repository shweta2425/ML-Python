# %%
import os
import pandas as pd
import pandas.api.types as ptypes
import numpy as np
import seaborn as sb
from matplotlib import pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.svm import SVR
import warnings
warnings.filterwarnings('ignore')
from sklearn.metrics import *
import pickle
import csv
from sklearn.metrics import accuracy_score

# %%
dataset1 = pd.read_csv("CSV_file/cv_data.csv")
x =dataset1.iloc[:,:-1].values
y =dataset1.iloc[:,1].values
dataset1.head()
# Out:
#           x         y
# 0  1.138682 -0.815304
# 1 -0.884667 -1.853992
# 2 -0.939800 -1.750123
# 3 -0.035632  1.469810
# 4  1.127656  1.054335

# %%
# check for num of rows and cols

print ('The train data has {0} rows and {1} columns'.format(dataset1.shape[0],dataset1.shape[1]))
# Out:
# The train data has 6944 rows and 2 columns

# %%
file = open('trainmodel.pkl', 'rb')
pickle_in = pickle.load(file)

# %%
class cross_validation_svm():

#     def load(self):
#         # dump train model pickle file
#         file = open('trainmodel.pkl', 'rb')
#         pickle_in = pickle.load(file)
    
    def predict(self,x,pickle_in):
     
        # predicting the test set result and train set result

        y_pred = pickle_in.predict(x)
        print("pred_cv",y_pred)
        return y_pred
        
    def accuracy(self,y,y_pred):
        print("\n\n ACCURACY \n\n")

        # acc using r2
        error = r2_score(y, y_pred)      
        acc_r2 = (1-error)*100
       
        # using median_ab_error
        median_ab_error = median_absolute_error(y, y_pred)
        return acc_r2, median_ab_error
        
    def plotting(self,x,y,y_pred):
        # visualising the training set results

        print("\n visualising using SVR \n ")
        plt.scatter(x, y , color = 'pink')
        plt.plot(x, y_pred, color = 'red')
        plt.title("Truth or Bulff(SVR)")
        plt.xlabel("Position Level")
        plt.ylabel("Salary")
        plt.show()

        print("\n visualising Regression Model \n ")
        plt.scatter(x, y, color ='red')
        plt.plot(x, y_pred, color ='green')
        plt.title('Truth or Bluff (Reg Model)')
        plt.xlabel('Position level')
        plt.ylabel('Salary')
        plt.show()
    
        
def main(x,y):
    
    object_SVM =  cross_validation_svm()
    
#     pickle_in = object_SVM.load()    
      
    y_pred = object_SVM.predict(x,pickle_in)
        
    acc_r2,median_ab_error = object_SVM.accuracy(y,y_pred)
    print("\n Accuracy train data acc_r2 : ", acc_r2)
    print("\n Accuracy train data median_ab_error : ",  median_ab_error)
    
    object_SVM.plotting(x,y,y_pred)
    
        
    
main(x,y)
# Out:
# pred_cv [ 0.71710926 -0.5982563  -0.57759048 ... -0.02163466  0.74620661
#   0.94102554]
#
#
#  ACCURACY
#
#
#
#  Accuracy train data acc_r2 :  81.91850212742422
#
#  Accuracy train data median_ab_error :  0.6935526442604708
#
#  visualising using SVR
#  visualising Regression Model
